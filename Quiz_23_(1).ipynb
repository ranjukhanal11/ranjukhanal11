# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjukhanal11/ranjukhanal11/blob/main/Quiz_23_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Below we can see the bar graph.
# https://www150.statcan.gc.ca/n1/edu/power-pouvoir/c-g/c-g05-2-1-eng.png. This graph is representing the number of police offices in a city from 2011 to 2019. In this graph we can that the by looking at graph, we can see that it is a good explanation of data.![1.png](data:image/png;base64,...)

# %% [markdown]
# In this graph, we can see that (https://www150.statcan.gc.ca/n1/edu/power-pouvoir/c-g/c-g05-4-6-eng.png) smoking frequency of boys and girls is shown in the graph. we can eaisly see that this graph is explaning the data very efficiently. by looking at the graph, we can find that this is an example integrity of data.![2.png](data:image/png;base64,...)
