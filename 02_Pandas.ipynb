# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjukhanal11/ranjukhanal11/blob/main/02_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing libraries and Data

# %%
import pandas as pd
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data',header = None)
head = ['Class','Alcohol','MalicAcid','Ash','AlcalinityAsh','Magnesium','Phenols','Flavanoids','NonflavanoidPhenols','Proanthocyanins','ColorIntensity','Hue','OD280/OD315','Proline'] 
#https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.names more info on the data file than you could ever use!
df.columns = head
df.head()
# Out:
#    Class  Alcohol  MalicAcid   Ash  ...  ColorIntensity   Hue  OD280/OD315  Proline
# 0      1    14.23       1.71  2.43  ...            5.64  1.04         3.92     1065
# 1      1    13.20       1.78  2.14  ...            4.38  1.05         3.40     1050
# 2      1    13.16       2.36  2.67  ...            5.68  1.03         3.17     1185
# 3      1    14.37       1.95  2.50  ...            7.80  0.86         3.45     1480
# 4      1    13.24       2.59  2.87  ...            4.32  1.04         2.93      735
#
# [5 rows x 14 columns]

# %% [markdown]
# # Statistical Analysis
# - Columns
# - Total Rows
# - Mean
# - Median
# - Mode
# - Graphical Analysis

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'MalicAcid', 'Ash', 'AlcalinityAsh', 'Magnesium',
#        'Phenols', 'Flavanoids', 'NonflavanoidPhenols', 'Proanthocyanins',
#        'ColorIntensity', 'Hue', 'OD280/OD315', 'Proline'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Class     Alcohol   MalicAcid  ...         Hue  OD280/OD315      Proline
# count  178.000000  178.000000  178.000000  ...  178.000000   178.000000   178.000000
# mean     1.938202   13.000618    2.336348  ...    0.957449     2.611685   746.893258
# std      0.775035    0.811827    1.117146  ...    0.228572     0.709990   314.907474
# min      1.000000   11.030000    0.740000  ...    0.480000     1.270000   278.000000
# 25%      1.000000   12.362500    1.602500  ...    0.782500     1.937500   500.500000
# 50%      2.000000   13.050000    1.865000  ...    0.965000     2.780000   673.500000
# 75%      3.000000   13.677500    3.082500  ...    1.120000     3.170000   985.000000
# max      3.000000   14.830000    5.800000  ...    1.710000     4.000000  1680.000000
#
# [8 rows x 14 columns]

# %%
df[['Class','Alcohol']].groupby('Class').sum().plot.bar(figsize=(10,10))

# %%
df[['Class','MalicAcid']].groupby('Class').sum().plot.bar(figsize=(10,10))
