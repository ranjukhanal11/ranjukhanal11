# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjukhanal11/ranjukhanal11/blob/main/01_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #a matrix like package for handling data
import pandas as pd #a R like package for handling data
from scipy import stats #a way to just get a piece of a large package
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("https://raw.githubusercontent.com/nurfnick/Data_Viz/main/iris.csv")

# %%
data.head()
# Out:
#    SepalLength  SepalWidth  PedalLength  PedalWidth        Class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
print(data.shape)
# Out:
# (150, 5)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PedalLength  150 non-null    float64
#  3   PedalWidth   150 non-null    float64
#  4   Class        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
ax=plt.subplots(1,1,figsize=(10,8))
sns.countplot('Class',data=data)
plt.title("Iris Species Count")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.hist(edgecolor='black', linewidth=1.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa482958c90>,
# ...
#       dtype=object)

# %%
data.boxplot(by="Class",figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa4827c4ed0>,
# ...
#       dtype=object)

# %%
sns.violinplot(data=data,x="Class", y="PedalLength")

# %%
from pandas.plotting import scatter_matrix
# scatter plot matrix
scatter_matrix(data,figsize=(10,10))
plt.show()
