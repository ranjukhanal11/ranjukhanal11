# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://go.gale.com/ps/i.do?id=GALE%7CA297733368&sid=googleScholar&v=2.1&it=r&linkaccess=abs&issn=10725830&p=AONE&sw=w&userGroupName=anon%7E58c30aad

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://go.gale.com/ps/i.do?id=GALE%7CA297733368&sid=googleScholar&v=2.1&it=r&linkaccess=abs&issn=10725830&p=AONE&sw=w&userGroupName=anon%7E636a8d1d

# %% [markdown]
# We can see that the above graphs are not showig the excellence. THe reason is that in both graphs, the data is smae but the graphs are dipicting differently.
# Graphs are not showing the same data on both graphs.
# thats why these graphs are not excellent
